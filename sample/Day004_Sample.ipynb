# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11533792606","type":"DeleteEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":5347074,"name":"webpack/webpack-dev-middleware","url":"https://api.github.com/repos/webpack/webpack-dev-middleware"},"payload":{"ref":"renovate/patch-all-patch-dependencies","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2020-02-17T09:02:43Z","org":{"id":2105791,"login":"webpack","gravatar_id":"","url":"https://api.github.com/orgs/webpack","avatar_url":"https://avatars.githubusercontent.com/u/2105791?"}},{"id":"11533792597","type":"PushEvent","actor":{"id":7457445,"login":"Eusebiotrigo","display_login":"Eusebiotrigo","gravatar_id":"","url":"https://api.github.com/users/Eusebiotrigo","avatar_url":"https://avatars.githubusercontent.com/u/7457445?"},"repo":{"id":203414375,"name":"Eusebiotrigo/intellij-settings","url":"https://api.github.com/repos/Eusebiotrigo/intellij-settings"},"payload":{"push_id":4640451228,"size":4,"distinct_size":4,"ref":"refs/heads/master","head":"49d8a87a8df54fe650ba54787996f94fa81cc727","before":"dfa62491b3d68bde8204202888e012081a7df26f","commits":[{"sha":"c5851c849adcd6816200bd6f728e302b2f48cc98","author":{"email":"damian.perez@e2ycommerce.com","name":"Damian Perez"},"message":"IU-2019.3.3 <admin@e2y-dev-es-03 Update find.xml","distinct":true,"url":"https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/c5851c849adcd6816200bd6f728e302b2f48cc98"},{"sha":"e2de89197e16d51979980ac9135613a43f16d321","author":{"email":"damian.perez@e2ycommerce.com","name":"Damian Perez"},"message":"IU-2019.3.3 <admin@e2y-dev-es-03 Update find.xml","distinct":true,"url":"https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/e2de89197e16d51979980ac9135613a43f16d321"},{"sha":"266e9b47166d896fcf681adc64d5f2e4641ab384","author":{"email":"damian.perez@e2ycommerce.com","name":"Damian Perez"},"message":"IU-2019.3.3 <admin@e2y-dev-es-03 Update find.xml","distinct":true,"url":"https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/266e9b47166d896fcf681adc64d5f2e4641ab384"},{"sha":"49d8a87a8df54fe650ba54787996f94fa81cc727","author":{"email":"damian.perez@e2ycommerce.com","name":"Damian Perez"},"message":"IU-2019.3.3 <admin@e2y-dev-es-03 Merge branch \'master\'","distinct":true,"url":"https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/49d8a87a8df54fe650ba54787996f94fa81cc727"}]},"public":true,"created_at":"2020-02-17T09:02:43Z"},{"id":"11533792586","type":"PushEvent","actor":{"id":36254304,"login":"jiyunlim","display_login":"jiyunlim","gravatar_id":"","url":"https://api.github.com/users/jiyunlim","avatar_url":"https://avatars.githubusercontent.com/u/36254304?"},"repo":{"id":237150146,"name":"jiyunlim/portfolio_directory01","url":"https://api.github.com/repos/jiyunlim/portfolio_directory01"},"payload":{"push_id":4640451208,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"74924c0f7154a463d299d2b2777473192b0277ac","before":"230498f87792649527108649ef9f4da048d33b5c","commits":[{"sha":"74924c0f7154a463d299d2b2777473192b0277ac","author":{"email":"jiyunlim94@gmail.com","name":"jiyun lim"},"message":"20200217commit","distinct":true,"url":"https://api.github.com/repos/jiyunlim/portfolio_directory01/commits/74924c0f7154a463d299d2b2777473192b0277ac"}]},"public":true,"created_at":"2020-02-17T09:02:43Z"},{"id":"11533792580","type":"PushEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":197258223,"name":"tim-hub/TrackersAway","url":"https://api.github.com/repos/tim-hub/TrackersAway"},"payload":{"push_id":4640451211,"size":7,"distinct_size":1,"ref":"refs/heads/renovate/mocha-6.x","head":"93b1f26b34fce05d07087e340765e6c3449316bc"," ...

# %%
import json

json.loads(r.text)
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'id': 29139614,
#    'login': 'renovate[bot]',
#    'url': 'https://api.github.com/users/renovate[bot]'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792606',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/2105791?',
#    'gravatar_id': '',
#    'id': 2105791,
#    'login': 'webpack',
#    'url': 'https://api.github.com/orgs/webpack'},
#   'payload': {'pusher_type': 'user',
#    'ref': 'renovate/patch-all-patch-dependencies',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 5347074,
#    'name': 'webpack/webpack-dev-middleware',
#    'url': 'https://api.github.com/repos/webpack/webpack-dev-middleware'},
#   'type': 'DeleteEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/7457445?',
#    'display_login': 'Eusebiotrigo',
#    'gravatar_id': '',
#    'id': 7457445,
#    'login': 'Eusebiotrigo',
#    'url': 'https://api.github.com/users/Eusebiotrigo'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792597',
#   'payload': {'before': 'dfa62491b3d68bde8204202888e012081a7df26f',
#    'commits': [{'author': {'email': 'damian.perez@e2ycommerce.com',
#       'name': 'Damian Perez'},
#      'distinct': True,
#      'message': 'IU-2019.3.3 <admin@e2y-dev-es-03 Update find.xml',
#      'sha': 'c5851c849adcd6816200bd6f728e302b2f48cc98',
#      'url': 'https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/c5851c849adcd6816200bd6f728e302b2f48cc98'},
#     {'author': {'email': 'damian.perez@e2ycommerce.com',
#       'name': 'Damian Perez'},
#      'distinct': True,
#      'message': 'IU-2019.3.3 <admin@e2y-dev-es-03 Update find.xml',
#      'sha': 'e2de89197e16d51979980ac9135613a43f16d321',
#      'url': 'https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/e2de89197e16d51979980ac9135613a43f16d321'},
#     {'author': {'email': 'damian.perez@e2ycommerce.com',
#       'name': 'Damian Perez'},
#      'distinct': True,
#      'message': 'IU-2019.3.3 <admin@e2y-dev-es-03 Update find.xml',
#      'sha': '266e9b47166d896fcf681adc64d5f2e4641ab384',
#      'url': 'https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/266e9b47166d896fcf681adc64d5f2e4641ab384'},
#     {'author': {'email': 'damian.perez@e2ycommerce.com',
#       'name': 'Damian Perez'},
#      'distinct': True,
#      'message': "IU-2019.3.3 <admin@e2y-dev-es-03 Merge branch 'master'",
#      'sha': '49d8a87a8df54fe650ba54787996f94fa81cc727',
#      'url': 'https://api.github.com/repos/Eusebiotrigo/intellij-settings/commits/49d8a87a8df54fe650ba54787996f94fa81cc727'}],
#    'distinct_size': 4,
#    'head': '49d8a87a8df54fe650ba54787996f94fa81cc727',
#    'push_id': 4640451228,
#    'ref': 'refs/heads/master',
#    'size': 4},
#   'public': True,
#   'repo': {'id': 203414375,
#    'name': 'Eusebiotrigo/intellij-settings',
#    'url': 'https://api.github.com/repos/Eusebiotrigo/intellij-settings'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/36254304?',
#    'display_login': 'jiyunlim',
#    'gravatar_id': '',
#    'id': 36254304,
#    'login': 'jiyunlim',
#    'url': 'https://api.github.com/users/jiyunlim'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792586',
#   'payload': {'before': '230498f87792649527108649ef9f4da048d33b5c',
#    'commits': [{'author': {'email': 'jiyunlim94@gmail.com',
#       'name': 'jiyun lim'},
#      'distinct': True,
#      'message': '20200217commit',
#      'sha': '74924c0f7154a463d299d2b2777473192b0277ac',
#      'url': 'https://api.github.com/repos/jiyunlim/portfolio_directory01/commits/74924c0f7154a463d299d2b2777473192b0277ac'}],
#    'distinct_size': 1,
#    'head': '74924c0f7154a463d299d2b2777473192b0277ac',
#    'push_id': 4640451208,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 237150146,
#    'name': 'jiyunlim/portfolio_directory01',
#    'url': 'https://api.github.com/repos/jiyunlim/portfolio_directory01'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'id': 29139614,
#    'login': 'renovate[bot]',
#    'url': 'https://api.github.com/users/renovate[bot]'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792580',
#   'payload': {'before': '8b1af80f46d1ea975ad105f88c3cc89cf9098a39',
#    'commits': [{'author': {'email': 'bot@renovateapp.com',
#       'name': 'Renovate Bot'},
#      'distinct': False,
#      'message': 'Update dependency redux to v4.0.5',
#      'sha': '73b0f5f1a2705c7cfa8efa5ff5bf3a196ec1f4ed',
#      'url': 'https://api.github.com/repos/tim-hub/TrackersAway/commits/73b0f5f1a2705c7cfa8efa5ff5bf3a196ec1f4ed'},
#     {'author': {'email': 'bot@renovateapp.com', 'name': 'Renovate Bot'},
#      'distinct': False,
#      'message': 'Update dependency axios to v0.19.2',
#      'sha': '30a6699c54556fd53b755147c4b4a015de287868',
#      'url': 'https://api.github.com/repos/tim-hub/TrackersAway/commits/30a6699c54556fd53b755147c4b4a015de287868'},
#     {'author': {'email': 'bot@renovateapp.com', 'name': 'Renovate Bot'},
#      'distinct': False,
#      'message': 'Update dependency electron-builder to v22',
#      'sha': '482e9bcf85d0d2f32168d8c323ca38c60a622246',
#      'url': 'https://api.github.com/repos/tim-hub/TrackersAway/commits/482e9bcf85d0d2f32168d8c323ca38c60a622246'},
#     {'author': {'email': 'tim-hub@users.noreply.github.com', 'name': 'Tim'},
#      'distinct': False,
#      'message': 'Merge pull request #23 from tim-hub/renovate/electron-builder-22.x\n\nUpdate dependency electron-builder to v22',
#      'sha': 'ecb088ae9635da79b137e92ba0499409fa67cc14',
#      'url': 'https://api.github.com/repos/tim-hub/TrackersAway/commits/ecb088ae9635da79b137e92ba0499409fa67cc14'},
#     {'author': {'email': 'tim-hub@users.noreply.github.com', 'name': 'Tim'},
#      'distinct': False,
#      'message': 'Merge pull request #21 from tim-hub/renovate/redux-4.x\n\nUpdate dependency redux to v4.0.5',
#      'sha': '765e06f5a08741e9982a34a629e4b3055bf89bf3',
#      'url': 'https://api.github.com/repos/tim-hub/TrackersAway/commits/765e06f5a08741e9982a34a629e4b3055bf89bf3'},
#     {'author': {'email': 'tim-hub@users.noreply.github.com', 'name': 'Tim'},
#      'distinct': False,
#      'message': 'Merge pull request #22 from tim-hub/renovate/axios-0.x\n\nUpdate dependency axios to v0.19.2',
#      'sha': '33cdc22342ad606ac9157dc51457094196beda05',
#      'url': 'https://api.github.com/repos/tim-hub/TrackersAway/commits/33cdc22342ad606ac9157dc51457094196beda05'},
#     {'author': {'email': 'bot@renovateapp.com', 'name': 'Renovate Bot'},
#      'distinct': True,
#      'message': 'Update dependency mocha to v6.2.2',
#      'sha': '93b1f26b34fce05d07087e340765e6c3449316bc',
#      'url': 'https://api.github.com/repos/tim-hub/TrackersAway/commits/93b1f26b34fce05d07087e340765e6c3449316bc'}],
#    'distinct_size': 1,
#    'head': '93b1f26b34fce05d07087e340765e6c3449316bc',
#    'push_id': 4640451211,
#    'ref': 'refs/heads/renovate/mocha-6.x',
#    'size': 7},
#   'public': True,
#   'repo': {'id': 197258223,
#    'name': 'tim-hub/TrackersAway',
#    'url': 'https://api.github.com/repos/tim-hub/TrackersAway'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/36063271?',
#    'display_login': 'enny06',
#    'gravatar_id': '',
#    'id': 36063271,
#    'login': 'enny06',
#    'url': 'https://api.github.com/users/enny06'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792581',
#   'payload': {'before': 'd32f3a8e569211efb42e7ba6896622384e69b4e5',
#    'commits': [{'author': {'email': 'enny.nuraini06@gmail.com',
#       'name': 'Enny'},
#      'distinct': True,
#      'message': 'enny06 2020/02/17 perbaikan usersgroup',
#      'sha': '390b66039ef5f64fb7cb7c246d60867478f2746b',
#      'url': 'https://api.github.com/repos/qsystem-online/eticketing/commits/390b66039ef5f64fb7cb7c246d60867478f2746b'}],
#    'distinct_size': 1,
#    'head': '390b66039ef5f64fb7cb7c246d60867478f2746b',
#    'push_id': 4640451215,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 232284122,
#    'name': 'qsystem-online/eticketing',
#    'url': 'https://api.github.com/repos/qsystem-online/eticketing'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/10869913?',
#    'display_login': 'dickydns',
#    'gravatar_id': '',
#    'id': 10869913,
#    'login': 'dickydns',
#    'url': 'https://api.github.com/users/dickydns'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792569',
#   'payload': {'before': 'fae95c16aa3b4f789c7daf57821393d9cb3bedc6',
#    'commits': [{'author': {'email': 'dickydraknes@gmail.com',
#       'name': 'DickyPerdian'},
#      'distinct': True,
#      'message': 'New Features are out!!!',
#      'sha': '5f5505bc102a6bef50223e52ffebba7f22e8fbc4',
#      'url': 'https://api.github.com/repos/dickydns/github-gardener/commits/5f5505bc102a6bef50223e52ffebba7f22e8fbc4'}],
#    'distinct_size': 1,
#    'head': '5f5505bc102a6bef50223e52ffebba7f22e8fbc4',
#    'push_id': 4640451199,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 133397409,
#    'name': 'dickydns/github-gardener',
#    'url': 'https://api.github.com/repos/dickydns/github-gardener'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/60249554?',
#    'display_login': '20171cse0067',
#    'gravatar_id': '',
#    'id': 60249554,
#    'login': '20171cse0067',
#    'url': 'https://api.github.com/users/20171cse0067'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792565',
#   'payload': {'before': 'a46d565b9a57e5c844f9d2530d7eadb427fc753c',
#    'commits': [{'author': {'email': '60249554+20171cse0067@users.noreply.github.com',
#       'name': '20171cse0067'},
#      'distinct': True,
#      'message': 'Add files via upload',
#      'sha': 'b2182d5e801d0a14d607e9f9943df7ca7d0506d6',
#      'url': 'https://api.github.com/repos/20171cse0067/it_256/commits/b2182d5e801d0a14d607e9f9943df7ca7d0506d6'}],
#    'distinct_size': 1,
#    'head': 'b2182d5e801d0a14d607e9f9943df7ca7d0506d6',
#    'push_id': 4640451207,
#    'ref': 'refs/heads/css',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 235944065,
#    'name': '20171cse0067/it_256',
#    'url': 'https://api.github.com/repos/20171cse0067/it_256'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/639533?',
#    'display_login': 'wzwmzm',
#    'gravatar_id': '',
#    'id': 639533,
#    'login': 'wzwmzm',
#    'url': 'https://api.github.com/users/wzwmzm'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792568',
#   'payload': {'before': '48a362b1913a76c23e7a65a4e31e1f2e162e1658',
#    'commits': [{'author': {'email': 'wzw_mzm@aliyun.com', 'name': 'wzwmzm'},
#      'distinct': True,
#      'message': 'a',
#      'sha': '706723673077e834ffd89c6a4ed61f73b5ff3d19',
#      'url': 'https://api.github.com/repos/wzwmzm/src/commits/706723673077e834ffd89c6a4ed61f73b5ff3d19'}],
#    'distinct_size': 1,
#    'head': '706723673077e834ffd89c6a4ed61f73b5ff3d19',
#    'push_id': 4640450953,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 235041433,
#    'name': 'wzwmzm/src',
#    'url': 'https://api.github.com/repos/wzwmzm/src'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/1153493?',
#    'display_login': 'bakoserge',
#    'gravatar_id': '',
#    'id': 1153493,
#    'login': 'bakoserge',
#    'url': 'https://api.github.com/users/bakoserge'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792561',
#   'payload': {'before': '8df15566ce3635946a5e6d702c9a33bfda8b769f',
#    'commits': [{'author': {'email': 'serge.bakayoko@lexisnexisrisk.com',
#       'name': 'serge bakayoko'},
#      'distinct': False,
#      'message': 'Replaced Animated.Text.propTypes.style by Text.propTypes.style causing issue on prod release and RN >= .0.62',
#      'sha': '729008b847eb38129d0b886e98253d4c11f6d4d3',
#      'url': 'https://api.github.com/repos/bakoserge/react-native-material-textfield/commits/729008b847eb38129d0b886e98253d4c11f6d4d3'},
#     {'author': {'email': 'bakoserge@gmail.com', 'name': 'serge'},
#      'distinct': True,
#      'message': 'Merge pull request #1 from bakoserge/Animated.Text.propTypes.style.error\n\nReplaced Animated.Text.propTypes.style by Text.propTypes.style causin…',
#      'sha': '8a8d7364c1aaa69f8f8d4214a2b435ffdc9fa443',
#      'url': 'https://api.github.com/repos/bakoserge/react-native-material-textfield/commits/8a8d7364c1aaa69f8f8d4214a2b435ffdc9fa443'}],
#    'distinct_size': 1,
#    'head': '8a8d7364c1aaa69f8f8d4214a2b435ffdc9fa443',
#    'push_id': 4640451205,
#    'ref': 'refs/heads/master',
#    'size': 2},
#   'public': True,
#   'repo': {'id': 239959872,
#    'name': 'bakoserge/react-native-material-textfield',
#    'url': 'https://api.github.com/repos/bakoserge/react-native-material-textfield'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/572096?',
#    'display_login': 'ovr',
#    'gravatar_id': '',
#    'id': 572096,
#    'login': 'ovr',
#    'url': 'https://api.github.com/users/ovr'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792564',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/53126077?',
#    'gravatar_id': '',
#    'id': 53126077,
#    'login': 'underjs',
#    'url': 'https://api.github.com/orgs/underjs'},
#   'payload': {'pusher_type': 'user',
#    'ref': 'episode-16',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 198288724,
#    'name': 'underjs/underjs.ru',
#    'url': 'https://api.github.com/repos/underjs/underjs.ru'},
#   'type': 'DeleteEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/19770058?',
#    'display_login': 'jiayu-ch15',
#    'gravatar_id': '',
#    'id': 19770058,
#    'login': 'jiayu-ch15',
#    'url': 'https://api.github.com/users/jiayu-ch15'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792554',
#   'payload': {'description': 'PyTorch Implementation of MADDPG (Lowe et. al. 2017)',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'ppo',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 233386606,
#    'name': 'jiayu-ch15/maddpg-pytorch',
#    'url': 'https://api.github.com/repos/jiayu-ch15/maddpg-pytorch'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/36975475?',
#    'display_login': 'a7med58',
#    'gravatar_id': '',
#    'id': 36975475,
#    'login': 'a7med58',
#    'url': 'https://api.github.com/users/a7med58'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792545',
#   'payload': {'before': 'e755ab0642d6188ba2bddfa1bba2af6b2c104216',
#    'commits': [{'author': {'email': '36975475+a7med58@users.noreply.github.com',
#       'name': 'Ahmed Mohamed Ahmed Ragab'},
#      'distinct': True,
#      'message': 'This Shell To Check Internet Connection',
#      'sha': 'dc5b7264e6e484fba2f17b755f2c6ccf1125fa60',
#      'url': 'https://api.github.com/repos/a7med58/Scan-Connection/commits/dc5b7264e6e484fba2f17b755f2c6ccf1125fa60'}],
#    'distinct_size': 1,
#    'head': 'dc5b7264e6e484fba2f17b755f2c6ccf1125fa60',
#    'push_id': 4640451200,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 241061912,
#    'name': 'a7med58/Scan-Connection',
#    'url': 'https://api.github.com/repos/a7med58/Scan-Connection'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/45942572?',
#    'display_login': 'SiarheiSakharevich',
#    'gravatar_id': '',
#    'id': 45942572,
#    'login': 'SiarheiSakharevich',
#    'url': 'https://api.github.com/users/SiarheiSakharevich'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792550',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/42994484?',
#    'gravatar_id': '',
#    'id': 42994484,
#    'login': 'saby',
#    'url': 'https://api.github.com/orgs/saby'},
#   'payload': {'pusher_type': 'user',
#    'ref': '20.2000/mergerator/170220_120238',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 155851629,
#    'name': 'saby/ui',
#    'url': 'https://api.github.com/repos/saby/ui'},
#   'type': 'DeleteEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/59165653?',
#    'display_login': 'edmams789',
#    'gravatar_id': '',
#    'id': 59165653,
#    'login': 'edmams789',
#    'url': 'https://api.github.com/users/edmams789'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792540',
#   'payload': {'before': 'db5843194463d879c0e1e31b25e0c9fd5384b086',
#    'commits': [{'author': {'email': '59165653+edmams789@users.noreply.github.com',
#       'name': 'edmams789'},
#      'distinct': True,
#      'message': '1 0 rename',
#      'sha': 'e4c24ea83f6615a6bfc74caef5f1de5a6f2b0f0e',
#      'url': 'https://api.github.com/repos/edmams789/topjava/commits/e4c24ea83f6615a6bfc74caef5f1de5a6f2b0f0e'},
#     {'author': {'email': '59165653+edmams789@users.noreply.github.com',
#       'name': 'edmams789'},
#      'distinct': True,
#      'message': '1 1 HW0 streams',
#      'sha': '613f25c4c03cf3e7f2b4f60df51401feb31046a6',
#      'url': 'https://api.github.com/repos/edmams789/topjava/commits/613f25c4c03cf3e7f2b4f60df51401feb31046a6'},
#     {'author': {'email': '59165653+edmams789@users.noreply.github.com',
#       'name': 'edmams789'},
#      'distinct': True,
#      'message': '1 2 HW0 cycles',
#      'sha': 'de07aeb20b0c44d6a72ac08fa345ee4e98f51733',
#      'url': 'https://api.github.com/repos/edmams789/topjava/commits/de07aeb20b0c44d6a72ac08fa345ee4e98f51733'},
#     {'author': {'email': '59165653+edmams789@users.noreply.github.com',
#       'name': 'edmams789'},
#      'distinct': True,
#      'message': '1 3 HW0 optional2',
#      'sha': 'b12da53762ecf6811d5977e1709eefc7c0b670fb',
#      'url': 'https://api.github.com/repos/edmams789/topjava/commits/b12da53762ecf6811d5977e1709eefc7c0b670fb'}],
#    'distinct_size': 4,
#    'head': 'b12da53762ecf6811d5977e1709eefc7c0b670fb',
#    'push_id': 4640451180,
#    'ref': 'refs/heads/master',
#    'size': 4},
#   'public': True,
#   'repo': {'id': 240659375,
#    'name': 'edmams789/topjava',
#    'url': 'https://api.github.com/repos/edmams789/topjava'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'id': 39814207,
#    'login': 'pull[bot]',
#    'url': 'https://api.github.com/users/pull[bot]'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792539',
#   'payload': {'action': 'closed',
#    'number': 1506,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/changeworld/azure-docs.de-de/issues/1506/comments'},
#      'commits': {'href': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/1506/commits'},
#      'html': {'href': 'https://github.com/changeworld/azure-docs.de-de/pull/1506'},
#      'issue': {'href': 'https://api.github.com/repos/changeworld/azure-docs.de-de/issues/1506'},
#      'review_comment': {'href': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/1506/comments'},
#      'self': {'href': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/1506'},
#      'statuses': {'href': 'https://api.github.com/repos/changeworld/azure-docs.de-de/statuses/415ee1d98053caba64a2a11be1af995a3d74be2f'}},
#     'additions': 3,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'NONE',
#     'base': {'label': 'changeworld:master',
#      'ref': 'master',
#      'repo': {'archive_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/branches{/branch}',
#       'clone_url': 'https://github.com/changeworld/azure-docs.de-de.git',
#       'collaborators_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/contributors',
#       'created_at': '2018-12-08T03:05:44Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/downloads',
#       'events_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/events',
#       'fork': True,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/forks',
#       'full_name': 'changeworld/azure-docs.de-de',
#       'git_commits_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/git/tags{/sha}',
#       'git_url': 'git://github.com/changeworld/azure-docs.de-de.git',
#       'has_downloads': True,
#       'has_issues': False,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/hooks',
#       'html_url': 'https://github.com/changeworld/azure-docs.de-de',
#       'id': 160898738,
#       'issue_comment_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/labels{/name}',
#       'language': 'PowerShell',
#       'languages_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/languages',
#       'license': {'key': 'other',
#        'name': 'Other',
#        'node_id': 'MDc6TGljZW5zZTA=',
#        'spdx_id': 'NOASSERTION',
#        'url': None},
#       'merges_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/merges',
#       'milestones_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/milestones{/number}',
#       'mirror_url': None,
#       'name': 'azure-docs.de-de',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjA4OTg3Mzg=',
#       'notifications_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/notifications{?since,all,participating}',
#       'open_issues': 0,
#       'open_issues_count': 0,
#       'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/1207985?v=4',
#        'events_url': 'https://api.github.com/users/changeworld/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/changeworld/followers',
#        'following_url': 'https://api.github.com/users/changeworld/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/changeworld/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/changeworld',
#        'id': 1207985,
#        'login': 'changeworld',
#        'node_id': 'MDQ6VXNlcjEyMDc5ODU=',
#        'organizations_url': 'https://api.github.com/users/changeworld/orgs',
#        'received_events_url': 'https://api.github.com/users/changeworld/received_events',
#        'repos_url': 'https://api.github.com/users/changeworld/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/changeworld/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/changeworld/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/changeworld'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls{/number}',
#       'pushed_at': '2020-02-17T09:02:42Z',
#       'releases_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/releases{/id}',
#       'size': 2141678,
#       'ssh_url': 'git@github.com:changeworld/azure-docs.de-de.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/stargazers',
#       'statuses_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/subscribers',
#       'subscription_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/subscription',
#       'svn_url': 'https://github.com/changeworld/azure-docs.de-de',
#       'tags_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/tags',
#       'teams_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/teams',
#       'trees_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/git/trees{/sha}',
#       'updated_at': '2020-02-17T05:02:10Z',
#       'url': 'https://api.github.com/repos/changeworld/azure-docs.de-de',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': '3d865c032e8e6bccd9768f27f8d6ca9892a4be45',
#      'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/1207985?v=4',
#       'events_url': 'https://api.github.com/users/changeworld/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/changeworld/followers',
#       'following_url': 'https://api.github.com/users/changeworld/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/changeworld/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/changeworld',
#       'id': 1207985,
#       'login': 'changeworld',
#       'node_id': 'MDQ6VXNlcjEyMDc5ODU=',
#       'organizations_url': 'https://api.github.com/users/changeworld/orgs',
#       'received_events_url': 'https://api.github.com/users/changeworld/received_events',
#       'repos_url': 'https://api.github.com/users/changeworld/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/changeworld/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/changeworld/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/changeworld'}},
#     'body': 'See [Commits](/changeworld/azure-docs.de-de/pull/1506/commits) and [Changes](/changeworld/azure-docs.de-de/pull/1506/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)',
#     'changed_files': 1,
#     'closed_at': '2020-02-17T09:02:42Z',
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/issues/1506/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/1506/commits',
#     'created_at': '2020-02-17T09:02:38Z',
#     'deletions': 3,
#     'diff_url': 'https://github.com/changeworld/azure-docs.de-de/pull/1506.diff',
#     'head': {'label': 'MicrosoftDocs:master',
#      'ref': 'master',
#      'repo': {'archive_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/branches{/branch}',
#       'clone_url': 'https://github.com/MicrosoftDocs/azure-docs.de-de.git',
#       'collaborators_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/contributors',
#       'created_at': '2016-11-09T19:03:15Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/downloads',
#       'events_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/events',
#       'fork': False,
#       'forks': 91,
#       'forks_count': 91,
#       'forks_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/forks',
#       'full_name': 'MicrosoftDocs/azure-docs.de-de',
#       'git_commits_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/git/tags{/sha}',
#       'git_url': 'git://github.com/MicrosoftDocs/azure-docs.de-de.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/hooks',
#       'html_url': 'https://github.com/MicrosoftDocs/azure-docs.de-de',
#       'id': 73312827,
#       'issue_comment_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/labels{/name}',
#       'language': 'PowerShell',
#       'languages_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/languages',
#       'license': {'key': 'other',
#        'name': 'Other',
#        'node_id': 'MDc6TGljZW5zZTA=',
#        'spdx_id': 'NOASSERTION',
#        'url': None},
#       'merges_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/merges',
#       'milestones_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/milestones{/number}',
#       'mirror_url': None,
#       'name': 'azure-docs.de-de',
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3MzMxMjgyNw==',
#       'notifications_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/notifications{?since,all,participating}',
#       'open_issues': 4,
#       'open_issues_count': 4,
#       'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/22479449?v=4',
#        'events_url': 'https://api.github.com/users/MicrosoftDocs/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/MicrosoftDocs/followers',
#        'following_url': 'https://api.github.com/users/MicrosoftDocs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MicrosoftDocs/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/MicrosoftDocs',
#        'id': 22479449,
#        'login': 'MicrosoftDocs',
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyNDc5NDQ5',
#        'organizations_url': 'https://api.github.com/users/MicrosoftDocs/orgs',
#        'received_events_url': 'https://api.github.com/users/MicrosoftDocs/received_events',
#        'repos_url': 'https://api.github.com/users/MicrosoftDocs/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/MicrosoftDocs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MicrosoftDocs/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/MicrosoftDocs'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/pulls{/number}',
#       'pushed_at': '2020-02-17T08:07:38Z',
#       'releases_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/releases{/id}',
#       'size': 2141672,
#       'ssh_url': 'git@github.com:MicrosoftDocs/azure-docs.de-de.git',
#       'stargazers_count': 13,
#       'stargazers_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/stargazers',
#       'statuses_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/subscription',
#       'svn_url': 'https://github.com/MicrosoftDocs/azure-docs.de-de',
#       'tags_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/tags',
#       'teams_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/teams',
#       'trees_url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de/git/trees{/sha}',
#       'updated_at': '2020-02-17T08:07:40Z',
#       'url': 'https://api.github.com/repos/MicrosoftDocs/azure-docs.de-de',
#       'watchers': 13,
#       'watchers_count': 13},
#      'sha': '415ee1d98053caba64a2a11be1af995a3d74be2f',
#      'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/22479449?v=4',
#       'events_url': 'https://api.github.com/users/MicrosoftDocs/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/MicrosoftDocs/followers',
#       'following_url': 'https://api.github.com/users/MicrosoftDocs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MicrosoftDocs/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/MicrosoftDocs',
#       'id': 22479449,
#       'login': 'MicrosoftDocs',
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyNDc5NDQ5',
#       'organizations_url': 'https://api.github.com/users/MicrosoftDocs/orgs',
#       'received_events_url': 'https://api.github.com/users/MicrosoftDocs/received_events',
#       'repos_url': 'https://api.github.com/users/MicrosoftDocs/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/MicrosoftDocs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MicrosoftDocs/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/MicrosoftDocs'}},
#     'html_url': 'https://github.com/changeworld/azure-docs.de-de/pull/1506',
#     'id': 376018151,
#     'issue_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/issues/1506',
#     'labels': [{'color': 'ededed',
#       'default': False,
#       'description': None,
#       'id': 1352295189,
#       'name': ':arrow_heading_down: pull',
#       'node_id': 'MDU6TGFiZWwxMzUyMjk1MTg5',
#       'url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/labels/:arrow_heading_down:%20pull'}],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': '415ee1d98053caba64a2a11be1af995a3d74be2f',
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': True,
#     'merged_at': '2020-02-17T09:02:42Z',
#     'merged_by': {'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/apps/pull',
#      'id': 39814207,
#      'login': 'pull[bot]',
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'type': 'Bot',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D'},
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzc2MDE4MTUx',
#     'number': 1506,
#     'patch_url': 'https://github.com/changeworld/azure-docs.de-de/pull/1506.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/1506/comments',
#     'state': 'closed',
#     'statuses_url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/statuses/415ee1d98053caba64a2a11be1af995a3d74be2f',
#     'title': '[pull] master from MicrosoftDocs:master',
#     'updated_at': '2020-02-17T09:02:42Z',
#     'url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/pulls/1506',
#     'user': {'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/apps/pull',
#      'id': 39814207,
#      'login': 'pull[bot]',
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'type': 'Bot',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D'}}},
#   'public': True,
#   'repo': {'id': 160898738,
#    'name': 'changeworld/azure-docs.de-de',
#    'url': 'https://api.github.com/repos/changeworld/azure-docs.de-de'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/57526420?',
#    'display_login': 'Anassifi',
#    'gravatar_id': '',
#    'id': 57526420,
#    'login': 'Anassifi',
#    'url': 'https://api.github.com/users/Anassifi'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792530',
#   'payload': {'action': 'added',
#    'member': {'avatar_url': 'https://avatars1.githubusercontent.com/u/58041410?v=4',
#     'events_url': 'https://api.github.com/users/chiamae/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/chiamae/followers',
#     'following_url': 'https://api.github.com/users/chiamae/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/chiamae/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/chiamae',
#     'id': 58041410,
#     'login': 'chiamae',
#     'node_id': 'MDQ6VXNlcjU4MDQxNDEw',
#     'organizations_url': 'https://api.github.com/users/chiamae/orgs',
#     'received_events_url': 'https://api.github.com/users/chiamae/received_events',
#     'repos_url': 'https://api.github.com/users/chiamae/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/chiamae/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/chiamae/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/chiamae'}},
#   'public': True,
#   'repo': {'id': 241060521,
#    'name': 'Anassifi/Sass-challenge',
#    'url': 'https://api.github.com/repos/Anassifi/Sass-challenge'},
#   'type': 'MemberEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/26767551?',
#    'display_login': 'poorali',
#    'gravatar_id': '',
#    'id': 26767551,
#    'login': 'poorali',
#    'url': 'https://api.github.com/users/poorali'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792523',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/13620684?',
#    'gravatar_id': '',
#    'id': 13620684,
#    'login': 'KaraWeb',
#    'url': 'https://api.github.com/orgs/KaraWeb'},
#   'payload': {'before': 'a9f4165c013ac1b7558120cffb126908876031ce',
#    'commits': [{'author': {'email': 'abolfazll.poorali@gmail.com',
#       'name': 'Abolfazll Poorali'},
#      'distinct': True,
#      'message': 'Implement search in movies',
#      'sha': '07687acf7defb3e29b3855ccf1bd11578314a726',
#      'url': 'https://api.github.com/repos/KaraWeb/chargereseller-film-dark/commits/07687acf7defb3e29b3855ccf1bd11578314a726'}],
#    'distinct_size': 1,
#    'head': '07687acf7defb3e29b3855ccf1bd11578314a726',
#    'push_id': 4640451168,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 234911629,
#    'name': 'KaraWeb/chargereseller-film-dark',
#    'url': 'https://api.github.com/repos/KaraWeb/chargereseller-film-dark'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/4058327?',
#    'display_login': 'nikolasburk',
#    'gravatar_id': '',
#    'id': 4058327,
#    'login': 'nikolasburk',
#    'url': 'https://api.github.com/users/nikolasburk'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792536',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/29239447?',
#    'gravatar_id': '',
#    'id': 29239447,
#    'login': 'howtographql',
#    'url': 'https://api.github.com/orgs/howtographql'},
#   'payload': {'action': 'closed',
#    'number': 1055,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/howtographql/howtographql/issues/1055/comments'},
#      'commits': {'href': 'https://api.github.com/repos/howtographql/howtographql/pulls/1055/commits'},
#      'html': {'href': 'https://github.com/howtographql/howtographql/pull/1055'},
#      'issue': {'href': 'https://api.github.com/repos/howtographql/howtographql/issues/1055'},
#      'review_comment': {'href': 'https://api.github.com/repos/howtographql/howtographql/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/howtographql/howtographql/pulls/1055/comments'},
#      'self': {'href': 'https://api.github.com/repos/howtographql/howtographql/pulls/1055'},
#      'statuses': {'href': 'https://api.github.com/repos/howtographql/howtographql/statuses/1411fecfbdbf704f3d057d080a13e4480b8fef07'}},
#     'additions': 64,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'NONE',
#     'base': {'label': 'howtographql:master',
#      'ref': 'master',
#      'repo': {'archive_url': 'https://api.github.com/repos/howtographql/howtographql/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/howtographql/howtographql/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/howtographql/howtographql/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/howtographql/howtographql/branches{/branch}',
#       'clone_url': 'https://github.com/howtographql/howtographql.git',
#       'collaborators_url': 'https://api.github.com/repos/howtographql/howtographql/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/howtographql/howtographql/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/howtographql/howtographql/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/howtographql/howtographql/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/howtographql/howtographql/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/howtographql/howtographql/contributors',
#       'created_at': '2017-06-06T21:30:25Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/howtographql/howtographql/deployments',
#       'description': 'The Fullstack Tutorial for GraphQL',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/howtographql/howtographql/downloads',
#       'events_url': 'https://api.github.com/repos/howtographql/howtographql/events',
#       'fork': False,
#       'forks': 829,
#       'forks_count': 829,
#       'forks_url': 'https://api.github.com/repos/howtographql/howtographql/forks',
#       'full_name': 'howtographql/howtographql',
#       'git_commits_url': 'https://api.github.com/repos/howtographql/howtographql/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/howtographql/howtographql/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/howtographql/howtographql/git/tags{/sha}',
#       'git_url': 'git://github.com/howtographql/howtographql.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': 'https://www.howtographql.com/',
#       'hooks_url': 'https://api.github.com/repos/howtographql/howtographql/hooks',
#       'html_url': 'https://github.com/howtographql/howtographql',
#       'id': 93565582,
#       'issue_comment_url': 'https://api.github.com/repos/howtographql/howtographql/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/howtographql/howtographql/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/howtographql/howtographql/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/howtographql/howtographql/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/howtographql/howtographql/labels{/name}',
#       'language': 'TypeScript',
#       'languages_url': 'https://api.github.com/repos/howtographql/howtographql/languages',
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'node_id': 'MDc6TGljZW5zZTEz',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit'},
#       'merges_url': 'https://api.github.com/repos/howtographql/howtographql/merges',
#       'milestones_url': 'https://api.github.com/repos/howtographql/howtographql/milestones{/number}',
#       'mirror_url': None,
#       'name': 'howtographql',
#       'node_id': 'MDEwOlJlcG9zaXRvcnk5MzU2NTU4Mg==',
#       'notifications_url': 'https://api.github.com/repos/howtographql/howtographql/notifications{?since,all,participating}',
#       'open_issues': 81,
#       'open_issues_count': 81,
#       'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/29239447?v=4',
#        'events_url': 'https://api.github.com/users/howtographql/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/howtographql/followers',
#        'following_url': 'https://api.github.com/users/howtographql/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/howtographql/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/howtographql',
#        'id': 29239447,
#        'login': 'howtographql',
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI5MjM5NDQ3',
#        'organizations_url': 'https://api.github.com/users/howtographql/orgs',
#        'received_events_url': 'https://api.github.com/users/howtographql/received_events',
#        'repos_url': 'https://api.github.com/users/howtographql/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/howtographql/starred{/owner}{/repo}',
# ...
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/SwingsNFI/Project_Absen_Telkom/pulls/4/comments',
#     'state': 'closed',
#     'statuses_url': 'https://api.github.com/repos/SwingsNFI/Project_Absen_Telkom/statuses/34d4e3f07c462d0f77350394c6038c6cda1436cc',
#     'title': 'Add files via upload',
#     'updated_at': '2020-02-17T09:02:42Z',
#     'url': 'https://api.github.com/repos/SwingsNFI/Project_Absen_Telkom/pulls/4',
#     'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/54987031?v=4',
#      'events_url': 'https://api.github.com/users/Calvinking2/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/Calvinking2/followers',
#      'following_url': 'https://api.github.com/users/Calvinking2/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Calvinking2/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/Calvinking2',
#      'id': 54987031,
#      'login': 'Calvinking2',
#      'node_id': 'MDQ6VXNlcjU0OTg3MDMx',
#      'organizations_url': 'https://api.github.com/users/Calvinking2/orgs',
#      'received_events_url': 'https://api.github.com/users/Calvinking2/received_events',
#      'repos_url': 'https://api.github.com/users/Calvinking2/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/Calvinking2/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Calvinking2/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/Calvinking2'}}},
#   'public': True,
#   'repo': {'id': 240907962,
#    'name': 'SwingsNFI/Project_Absen_Telkom',
#    'url': 'https://api.github.com/repos/SwingsNFI/Project_Absen_Telkom'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'id': 39814207,
#    'login': 'pull[bot]',
#    'url': 'https://api.github.com/users/pull[bot]'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792504',
#   'payload': {'before': '3d865c032e8e6bccd9768f27f8d6ca9892a4be45',
#    'commits': [{'author': {'email': 'olprod@microsoft.com', 'name': 'olprod'},
#      'distinct': True,
#      'message': 'commit translated contents',
#      'sha': '415ee1d98053caba64a2a11be1af995a3d74be2f',
#      'url': 'https://api.github.com/repos/changeworld/azure-docs.de-de/commits/415ee1d98053caba64a2a11be1af995a3d74be2f'}],
#    'distinct_size': 1,
#    'head': '415ee1d98053caba64a2a11be1af995a3d74be2f',
#    'push_id': 4640451172,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 160898738,
#    'name': 'changeworld/azure-docs.de-de',
#    'url': 'https://api.github.com/repos/changeworld/azure-docs.de-de'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/44804363?',
#    'display_login': 'Carlosch456',
#    'gravatar_id': '',
#    'id': 44804363,
#    'login': 'Carlosch456',
#    'url': 'https://api.github.com/users/Carlosch456'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792499',
#   'payload': {'before': 'a182ece890029973a3a6685746bcfadb01b6c0a9',
#    'commits': [{'author': {'email': 'carloschamorro80@gmail.com',
#       'name': 'carlosch456'},
#      'distinct': True,
#      'message': 'version',
#      'sha': '31f1ee2a0979a8d40a8906509f07243d430ade4c',
#      'url': 'https://api.github.com/repos/Carlosch456/Trabajo-TIC/commits/31f1ee2a0979a8d40a8906509f07243d430ade4c'}],
#    'distinct_size': 1,
#    'head': '31f1ee2a0979a8d40a8906509f07243d430ade4c',
#    'push_id': 4640451171,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 234533074,
#    'name': 'Carlosch456/Trabajo-TIC',
#    'url': 'https://api.github.com/repos/Carlosch456/Trabajo-TIC'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/296354?',
#    'display_login': 'hferentschik',
#    'gravatar_id': '',
#    'id': 296354,
#    'login': 'hferentschik',
#    'url': 'https://api.github.com/users/hferentschik'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792506',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/34566050?',
#    'gravatar_id': '',
#    'id': 34566050,
#    'login': 'jenkins-x',
#    'url': 'https://api.github.com/orgs/jenkins-x'},
#   'payload': {'action': 'created',
#    'comment': {'author_association': 'CONTRIBUTOR',
#     'body': '/test lint',
#     'created_at': '2020-02-17T09:02:42Z',
#     'html_url': 'https://github.com/jenkins-x/jx/pull/6494#issuecomment-586886105',
#     'id': 586886105,
#     'issue_url': 'https://api.github.com/repos/jenkins-x/jx/issues/6494',
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU4Njg4NjEwNQ==',
#     'updated_at': '2020-02-17T09:02:42Z',
#     'url': 'https://api.github.com/repos/jenkins-x/jx/issues/comments/586886105',
#     'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/296354?v=4',
#      'events_url': 'https://api.github.com/users/hferentschik/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/hferentschik/followers',
#      'following_url': 'https://api.github.com/users/hferentschik/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hferentschik/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/hferentschik',
#      'id': 296354,
#      'login': 'hferentschik',
#      'node_id': 'MDQ6VXNlcjI5NjM1NA==',
#      'organizations_url': 'https://api.github.com/users/hferentschik/orgs',
#      'received_events_url': 'https://api.github.com/users/hferentschik/received_events',
#      'repos_url': 'https://api.github.com/users/hferentschik/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/hferentschik/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hferentschik/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/hferentschik'}},
#    'issue': {'assignee': {'avatar_url': 'https://avatars0.githubusercontent.com/u/296354?v=4',
#      'events_url': 'https://api.github.com/users/hferentschik/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/hferentschik/followers',
#      'following_url': 'https://api.github.com/users/hferentschik/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hferentschik/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/hferentschik',
#      'id': 296354,
#      'login': 'hferentschik',
#      'node_id': 'MDQ6VXNlcjI5NjM1NA==',
#      'organizations_url': 'https://api.github.com/users/hferentschik/orgs',
#      'received_events_url': 'https://api.github.com/users/hferentschik/received_events',
#      'repos_url': 'https://api.github.com/users/hferentschik/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/hferentschik/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hferentschik/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/hferentschik'},
#     'assignees': [{'avatar_url': 'https://avatars0.githubusercontent.com/u/296354?v=4',
#       'events_url': 'https://api.github.com/users/hferentschik/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/hferentschik/followers',
#       'following_url': 'https://api.github.com/users/hferentschik/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/hferentschik/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/hferentschik',
#       'id': 296354,
#       'login': 'hferentschik',
#       'node_id': 'MDQ6VXNlcjI5NjM1NA==',
#       'organizations_url': 'https://api.github.com/users/hferentschik/orgs',
#       'received_events_url': 'https://api.github.com/users/hferentschik/received_events',
#       'repos_url': 'https://api.github.com/users/hferentschik/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/hferentschik/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/hferentschik/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/hferentschik'}],
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Step 2 towards : \r\n#2302 ',
#     'closed_at': None,
#     'comments': 13,
#     'comments_url': 'https://api.github.com/repos/jenkins-x/jx/issues/6494/comments',
#     'created_at': '2020-01-11T14:56:28Z',
#     'events_url': 'https://api.github.com/repos/jenkins-x/jx/issues/6494/events',
#     'html_url': 'https://github.com/jenkins-x/jx/pull/6494',
#     'id': 548439257,
#     'labels': [{'color': 'ededed',
#       'default': False,
#       'description': None,
#       'id': 1155870428,
#       'name': 'ok-to-test',
#       'node_id': 'MDU6TGFiZWwxMTU1ODcwNDI4',
#       'url': 'https://api.github.com/repos/jenkins-x/jx/labels/ok-to-test'},
#      {'color': 'ededed',
#       'default': False,
#       'description': None,
#       'id': 1016466107,
#       'name': 'size/L',
#       'node_id': 'MDU6TGFiZWwxMDE2NDY2MTA3',
#       'url': 'https://api.github.com/repos/jenkins-x/jx/labels/size/L'}],
#     'labels_url': 'https://api.github.com/repos/jenkins-x/jx/issues/6494/labels{/name}',
#     'locked': False,
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzYxNzM2Mjg0',
#     'number': 6494,
#     'pull_request': {'diff_url': 'https://github.com/jenkins-x/jx/pull/6494.diff',
#      'html_url': 'https://github.com/jenkins-x/jx/pull/6494',
#      'patch_url': 'https://github.com/jenkins-x/jx/pull/6494.patch',
#      'url': 'https://api.github.com/repos/jenkins-x/jx/pulls/6494'},
#     'repository_url': 'https://api.github.com/repos/jenkins-x/jx',
#     'state': 'open',
#     'title': 'feat: Ensure Kustomize',
#     'updated_at': '2020-02-17T09:02:42Z',
#     'url': 'https://api.github.com/repos/jenkins-x/jx/issues/6494',
#     'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/15074229?v=4',
#      'events_url': 'https://api.github.com/users/nehagup/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/nehagup/followers',
#      'following_url': 'https://api.github.com/users/nehagup/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nehagup/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/nehagup',
#      'id': 15074229,
#      'login': 'nehagup',
#      'node_id': 'MDQ6VXNlcjE1MDc0MjI5',
#      'organizations_url': 'https://api.github.com/users/nehagup/orgs',
#      'received_events_url': 'https://api.github.com/users/nehagup/received_events',
#      'repos_url': 'https://api.github.com/users/nehagup/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/nehagup/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nehagup/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/nehagup'}}},
#   'public': True,
#   'repo': {'id': 116400734,
#    'name': 'jenkins-x/jx',
#    'url': 'https://api.github.com/repos/jenkins-x/jx'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/26448561?',
#    'display_login': 'OPSTestProduction',
#    'gravatar_id': '',
#    'id': 26448561,
#    'login': 'OPSTestProduction',
#    'url': 'https://api.github.com/users/OPSTestProduction'},
#   'created_at': '2020-02-17T09:02:43Z',
#   'id': '11533792500',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/24789421?',
#    'gravatar_id': '',
#    'id': 24789421,
#    'login': 'OPS-E2E-Prod',
#    'url': 'https://api.github.com/orgs/OPS-E2E-Prod'},
#   'payload': {'before': '302ce6bee642f4da21a786e826e525b3d7836ccf',
#    'commits': [{'author': {'email': 'opse2etestingproduction@outlook.com',
#       'name': 'OPSTestProduction'},
#      'distinct': True,
#      'message': 'Incremental publish: add a content',
#      'sha': '525223e33d44ebf2fcb02bbbcfb0e0af2fc20211',
#      'url': 'https://api.github.com/repos/OPS-E2E-Prod/E2E_DocsBranch_Prod_Dynamic-v3/commits/525223e33d44ebf2fcb02bbbcfb0e0af2fc20211'}],
#    'distinct_size': 1,
#    'head': '525223e33d44ebf2fcb02bbbcfb0e0af2fc20211',
#    'push_id': 4640451167,
#    'ref': 'refs/heads/e2e-v3-incremental-addcontent',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 176674082,
#    'name': 'OPS-E2E-Prod/E2E_DocsBranch_Prod_Dynamic-v3',
#    'url': 'https://api.github.com/repos/OPS-E2E-Prod/E2E_DocsBranch_Prod_Dynamic-v3'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35869161?',
#    'display_login': 'gytaoyu',
#    'gravatar_id': '',
#    'id': 35869161,
#    'login': 'gytaoyu',
#    'url': 'https://api.github.com/users/gytaoyu'},
#   'created_at': '2020-02-17T09:02:42Z',
#   'id': '11533792489',
#   'payload': {'description': 'some files to help me to surf on the internet',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'master',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 241062208,
#    'name': 'gytaoyu/net_files',
#    'url': 'https://api.github.com/repos/gytaoyu/net_files'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/42369224?',
#    'display_login': 'seryozhakhachatryan',
#    'gravatar_id': '',
#    'id': 42369224,
#    'login': 'seryozhakhachatryan',
#    'url': 'https://api.github.com/users/seryozhakhachatryan'},
#   'created_at': '2020-02-17T09:02:42Z',
#   'id': '11533792469',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/58458659?',
#    'gravatar_id': '',
#    'id': 58458659,
#    'login': 'Skills-Matrix',
#    'url': 'https://api.github.com/orgs/Skills-Matrix'},
#   'payload': {'before': '1b1d69bc6aa079a34fad646d6176fbc6700ee99d',
#    'commits': [{'author': {'email': 'albert.aghajanyan.im@gmail.com',
#       'name': 'aaghajanyan'},
#      'distinct': True,
#      'message': '\tStarted to add branch page.',
#      'sha': '98dc50a8d43ffe54573c5b63daa847d4ef994f9f',
#      'url': 'https://api.github.com/repos/Skills-Matrix/skills-matrix-ui/commits/98dc50a8d43ffe54573c5b63daa847d4ef994f9f'}],
#    'distinct_size': 1,
#    'head': '98dc50a8d43ffe54573c5b63daa847d4ef994f9f',
#    'push_id': 4640451158,
#    'ref': 'refs/heads/category_feature_initial',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 225788981,
#    'name': 'Skills-Matrix/skills-matrix-ui',
#    'url': 'https://api.github.com/repos/Skills-Matrix/skills-matrix-ui'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/9011267?',
#    'display_login': 'dotnet-bot',
#    'gravatar_id': '',
#    'id': 9011267,
#    'login': 'dotnet-bot',
#    'url': 'https://api.github.com/users/dotnet-bot'},
#   'created_at': '2020-02-17T09:02:42Z',
#   'id': '11533792473',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/9141961?',
#    'gravatar_id': '',
#    'id': 9141961,
#    'login': 'dotnet',
#    'url': 'https://api.github.com/orgs/dotnet'},
#   'payload': {'pusher_type': 'user',
#    'ref': 'merges/master-to-master-vs-deps',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 29078997,
#    'name': 'dotnet/roslyn',
#    'url': 'https://api.github.com/repos/dotnet/roslyn'},
#   'type': 'DeleteEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/49155130?',
#    'display_login': 'ReBorn67',
#    'gravatar_id': '',
#    'id': 49155130,
#    'login': 'ReBorn67',
#    'url': 'https://api.github.com/users/ReBorn67'},
#   'created_at': '2020-02-17T09:02:42Z',
#   'id': '11533792460',
#   'payload': {'before': 'a809b0970cf5447e9ba615b216939997d765c5b5',
#    'commits': [{'author': {'email': '49155130+ReBorn67@users.noreply.github.com',
#       'name': 'ReBorn67'},
#      'distinct': True,
#      'message': 'search_bug_fix',
#      'sha': 'b65c3d419276c6c1627ed622f9480808d289fbcc',
#      'url': 'https://api.github.com/repos/ReBorn67/blog/commits/b65c3d419276c6c1627ed622f9480808d289fbcc'}],
#    'distinct_size': 1,
#    'head': 'b65c3d419276c6c1627ed622f9480808d289fbcc',
#    'push_id': 4640451156,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 227779640,
#    'name': 'ReBorn67/blog',
#    'url': 'https://api.github.com/repos/ReBorn67/blog'},
#   'type': 'PushEvent'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
