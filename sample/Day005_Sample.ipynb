],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":1194},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":39}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://megapx-assets.dcard.tw/images/65b90e00-3e16-48d8-b44d-11405fadee02/1280.jpeg"},{"url":"https://megapx-assets.dcard.tw/images/b19f6417-921e-4877-ad16-c47905f64245/1280.jpeg"},{"url":"https://megapx-assets.dcard.tw/images/977f93bd-e866-4d43-a842-4d2a0721f1ae/1280.jpeg"}],"reportReasonText":"","postAvatar":""},{"id":233086589,"title":"膠帶捉貓實驗😆","excerpt":"滑手機看到這張圖，回家之後立馬試試主子們，不囉嗦直接上影片，實驗證明：一個圈只能抓一隻貓，再來幾張萌照！，很久沒在滴卡發文了️，不知道還有沒有人記得我們～喵，目前奴才最喜歡的一張\U0001f92d","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-02-16T08:43:32.982Z","updatedAt":"2020-02-17T09:48:10.137Z","commentCount":36,"likeCount":904,"withNickname":false,"tags":[],"topics":["貓","白貓","寵物","實驗"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"中華醫事科技大學","replyTitle":null,"mediaMeta":[{"id":"df54f13e-273c-4a7e-8fb3-47a9d7d15496","url":"https://megapx-assets.dcard.tw/images/5f339be1-df77-48c2-8b75-38dc815b8c7d/640.jpeg","normalizedUrl":"https://megapx-assets.dcard.tw/images/5f339be1-df77-48c2-8b75-38dc815b8c7d/640.jpeg","thumbnail":"https://megapx-assets.dcard.tw/images/5f339be1-df77-48c2-8b75-38dc815b8c7d/640.jpeg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt" ...

# %%
import json
data = json.loads(response)

for d in data:
    print(d['title'])
# Out:
# 男友搬走貓兒子最爽
# 膠帶捉貓實驗😆
# 養了一隻很騷的貓（圖多）
# 狗狗也會賴床(˶‾᷄ ⁻̫ ‾᷅˵)
# #圖 天竺鼠戴眼鏡想帥鼠誰啊^-^
# 我家兔子的對象是顆球
# 情人節與浮誇玫瑰貓度過🌹
# 同學你的鳥寶太可愛🥺
# 緝凶各位幫幫忙
# 同學你的狗狗好可愛啊！
# 憂鬱狗狗系列，不能笑一下嗎？
# 點此獲得美味可口雞肉飯一隻
# 養了貓之後...#圖多話多
# 想睡覺會發脾氣
# 我家的逗逼兔子🐰
# 漂亮小母貓認養
# 貓咪長輩圖
# #有片 小笨狗你怎麼連玩具車都怕？
# 養了很久的魚死了😔😔
# 貓咪流眼淚（急）
# 蠢呆萌的主子娘娘
# 領養不棄養
# 睡覺💤zing
# 跟著我一起耍廢
# #問 有人知道這是哪一種狗狗嗎～
# 急～狗狗發出不明聲音
# 每天回家都會看到舞龍舞獅
# 急！！！
# #問 貓咪食量變差
# 出家人的行為嗎？

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
#     1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
#     2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
#     3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
