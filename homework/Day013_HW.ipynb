# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html5lib')

posts = []

for d in soup.find_all(class_='title'):
    title= d.text.replace('\n', '').replace('\t', '')
    print("title:", title)
    try:
        post = {}

        soup2 = BeautifulSoup(requests.get('https://www.ptt.cc{}'.format(d.find('a')['href'])).text, 'html5lib')
        print('https://www.ptt.cc{}'.format(d.find('a')['href']))
        print(soup2.find_all(class_="article-meta-tag"), ":", soup2.find_all(class_="article-meta-value"))
        print(soup2.find_all(class_="article-meta-tag")[0].text, ":", soup2.find_all(class_="article-meta-value")[0].text)
        print(soup2.find_all(class_="article-meta-tag")[2].text, ":", soup2.find_all(class_="article-meta-value")[2].text)
        print(soup2.find_all(class_="article-meta-tag")[3].text, ":", soup2.find_all(class_="article-meta-value")[3].text)
        print("")
        
        post['標題'] = soup2.find_all(class_="article-meta-value")[0].text
        post['作者'] = soup2.find_all(class_="article-meta-value")[2].text
        post['時間'] = soup2.find_all(class_="article-meta-value")[3].text
        
        posts.append(post)
        
        
    except:
        continue
posts = sorted(posts, key= lambda x: x['時間'])
print(posts[-1])
# Out:
# title: (本文已被刪除) [iphone15]
# title: [花邊] LBJ,AD,JR,Clarkson, Rich Paul一起騎車
# https://www.ptt.cc/bbs/NBA/M.1590902866.A.D0C.html
# [<span class="article-meta-tag">作者</span>, <span class="article-meta-tag">看板</span>, <span class="article-meta-tag">標題</span>, <span class="article-meta-tag">時間</span>] : [<span class="article-meta-value">kyle5241 (Kyle Korver)</span>, <span class="article-meta-value">NBA</span>, <span class="article-meta-value">[花邊] LBJ,AD,JR,Clarkson, Rich Paul一起騎車</span>, <span class="article-meta-value">Sun May 31 13:27:43 2020</span>]
# 作者 : kyle5241 (Kyle Korver)
# 標題 : [花邊] LBJ,AD,JR,Clarkson, Rich Paul一起騎車
# 時間 : Sun May 31 13:27:43 2020
#
# title: [討論] 18火箭面對以前的傳統強隊機會大嗎
# https://www.ptt.cc/bbs/NBA/M.1590907323.A.2C0.html
# ...

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''

url = "https://www.ptt.cc/bbs/Stock/index.html"
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html5lib')
for d in soup.find_all(class_='r-ent'):
    print("作者:", d.find(class_='author').text.replace('\n','').replace('\t', ''))
    print("標題:", d.find(class_='title').text.replace('\n','').replace('\t', ''))
    print("時間:", d.find(class_='date').text.replace('\n','').replace('\t', ''))
    print("")
# Out:
# 作者: a000000000
# 標題: Re: [新聞] 全美反警示威延燒 洛杉磯費城亞特蘭大宣
# 時間:  5/31
#
# 作者: gk1329
# 標題: Re: [新聞] 馬斯克的衛星網路計畫有了新進展，但疑點
# 時間:  5/31
#
# 作者: waitrop
# 標題: Re: [標的] 雪佛龍
# 時間:  5/31
#
# 作者: IanLi
# 標題: [公告] 精華區導覽Q&A
# 時間:  1/25
#
# 作者: eyespot
# 標題: [公告] Stock 板規V2.6             (2019/06/20)
# 時間: 11/03
#
# 作者: noldorelf
# 標題: [公告] 板規修正
# 時間:  4/28
#
# 作者: noldorelf
# 標題: [公告] 股票板板主徵選延長公告
# 時間:  5/19
#
# 作者: vendan5566
# 標題: [閒聊] 2020/05/29 盤後閒聊
# 時間:  5/29

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''

url = "https://www.ptt.cc/bbs/Beauty/index.html"
r = requests.get(url, cookies={'over18': '1'})
soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all(class_='r-ent'):
    try:
        print("作者:", d.find(class_='author').text.replace('\n','').replace('\t', ''))
        print("標題:", d.find(class_='title').text.replace('\n','').replace('\t', ''))
        print('路徑:', "https://www.ptt.cc{}".format(d.find('a')['href']))
        print("時間:", d.find(class_='date').text.replace('\n','').replace('\t', ''))
        print("")
    except:
        continue
# Out:
# 作者: t02858393619
# 標題: [正妹] 朋友學士服兩張
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590849542.A.823.html
# 時間:  5/30
#
# 作者: apexi6031
# 標題: [正妹] 韻律體操教練
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590851785.A.058.html
# 時間:  5/30
#
# 作者: ReiKuromiya
# 標題: [正妹] Robyn Betteridge(8)
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590856805.A.EF1.html
# 時間:  5/31
#
# 作者: asxc530530
# 標題: [正妹] 海景第一排
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590858581.A.A9A.html
# 時間:  5/31
#
# 作者: hizo
# 標題: [正妹] 長澤茉里奈 幾張
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590859684.A.519.html
# 時間:  5/31
#
# 作者: wafiea708
# 標題: [正妹] 請夏
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590859772.A.D88.html
# 時間:  5/31
#
# 作者: ckpot
# 標題: [正妹] 大尺碼｜肉特(88)
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590863076.A.A92.html
# 時間:  5/31
#
# 作者: ReiKuromiya
# 標題: [正妹] 長澤まさみ
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590865583.A.A2C.html
# 時間:  5/31
#
# 作者: Westbrook0
# 標題: [神人] 新聞內配圖
# 路徑: https://www.ptt.cc/bbs/Beauty/M.1590870369.A.EAD.html
# 時間:  5/31
#
# ...
