# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 利用 urllib 套件的 urlretrieve 方法下載檔案
# * 了解 Python File I/O 讀檔、寫檔的用法
# * 能用運用資源管理器 With Statement 優化寫法

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

'''
Your Code
'''
import requests

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text
print(response)
# Out:
# [{"id":232612477,"title":"同學你的貓貓","excerpt":"這位同學你的貓貓被通緝了快點交出來讓我吸個貓，他太可愛啦啦啦（=´∇｀=）","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-02T12:11:28.555Z","updatedAt":"2019-12-02T12:11:28.555Z","commentCount":31,"likeCount":1041,"withNickname":true,"tags":[],"topics":["貓貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"吃土少女(´･_･`)","department":"bbc1314","replyTitle":null,"mediaMeta":[{"id":"23e6fa37-7174-470a-be15-69f440043347","url":"https://i.imgur.com/xy93Pwal.jpg","normalizedUrl":"https://i.imgur.com/xy93Pwal.jpg","thumbnail":"https://i.imgur.com/xy93Pwal.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-02T12:11:28.555Z","updatedAt":"2019-12-02T12:11:28.555Z"},{"id":"23e6fa37-7174-470a-be15-69f440043347","url":"https://i.imgur.com/xy93Pwa.jpg","normalizedUrl":"https://imgur.com/xy93Pwa","thumbnail":"https://i.imgur.com/xy93Pwal.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T12:11:28.555Z","updatedAt":"2019-12-02T12:11:28.555Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":1031},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":10}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/xy93Pwa.jpg"}],"reportReasonText":"","postAvatar":""},{"id":232612340,"title":"我到底養了什麼貓....（...微西斯）","excerpt":"各位，禁止筆戰，我只是來分享我兒子的趣事🤣，他是異色瞳米克斯小白貓，2019/06/11出生的小雙子座，到現在已經五個多月了～但我好像把他養的有點胖過頭了⋯⋯，請看，這是9月剛來我家的時候，現在11","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z","commentCount":21,"likeCount":421,"withNickname":true,"tags":[],"topics":["貓","米克斯","可愛","寵物","白貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"Q滴小西","department":"j_es00","replyTitle":null,"mediaMeta":[{"id":"1bee85cb-4e04-487f-abaa-3642d4da4353","url":"https://i.imgur.com/OjNXStil.jpg","normalizedUrl":"https://i.imgur.com/OjNXStil.jpg","thumbnail":"https://i.imgur.com/OjNXStil.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"1bee85cb-4e04-487f-abaa-3642d4da4353","url":"https://i.imgur.com/OjNXSti.jpg","normalizedUrl":"https://imgur.com/OjNXSti","thumbnail":"https://i.imgur.com/OjNXStil.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"64c3698e-dd83-448c-89dd-2eb330ec25bf","url":"https://i.imgur.com/5g9nLQG.jpg","normalizedUrl":"https://imgur.com/5g9nLQG","thumbnail":"https://i.imgur.com/5g9nLQGl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"17fed8ae-78a2-4b33-bf61-d0dc931c2419","url":"https://www.dcard.tw/v2/vivid/videos/991faa28-e9af-48eb-91ad-d5a404222d74?r=1.7777777777777777","normalizedUrl":"","thumbnail":"https://vivid.dcard.tw/Public/991faa28-e9af-48eb-91ad-d5a404222d74/thumbnail.jpg","type":"video/vivid","tags":["ANNOTATED_FAILED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"2a0f89b7-8087-4f9d-bdad-e859345fcebf","url":"https://i.imgur.com/R8ER0Lt.jpg","normalizedUrl":"https://imgur.com/R8ER0Lt","thumbnail":"https://i.imgur.com/R8ER0Ltl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"cd8b139b-ac2e-4c97-8dca-7f58f968bc08","url":"https://i.imgur.com/LE9Zp79.jpg","normalizedUrl":"https://imgur.com/LE9Zp79","thumbnail":"https://i.imgur.com/LE9Zp79l.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"278bd9c1-62cc-4db0 ...

# %%
import json
data = json.loads(response)
print(len(data))
# Out:
# 30

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

'''
Your Code
'''

for d in data:
    print("標題: ", d['title'], " ; 貼文時間: " , d['createdAt'], " ; 留言人數: ", d['commentCount'], "; 按讚人數: ", d['likeCount'] )
# Out:
# 標題:  好像買太小了...  ; 貼文時間:  2019-12-01T08:27:28.504Z  ; 留言人數:  40 ; 按讚人數:  3746
# 標題:  我養的是工讀生？🤔  ; 貼文時間:  2019-12-01T02:07:09.729Z  ; 留言人數:  27 ; 按讚人數:  572
# 標題:  散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩  ; 貼文時間:  2019-12-02T02:51:47.393Z  ; 留言人數:  0 ; 按讚人數:  300
# 標題:  貓咪沒在尊重男友  ; 貼文時間:  2019-12-01T10:44:13.896Z  ; 留言人數:  6 ; 按讚人數:  115
# 標題:  如果當初這樣做 或許結局就能不同了吧  ; 貼文時間:  2019-12-01T00:49:18.221Z  ; 留言人數:  0 ; 按讚人數:  52
# 標題:  自嗨小橘貓  ; 貼文時間:  2019-11-30T20:21:16.782Z  ; 留言人數:  2 ; 按讚人數:  50
# 標題:  可以幫幫我推上熱門嗎急尋狗啟示  ; 貼文時間:  2019-12-01T17:56:16.299Z  ; 留言人數:  0 ; 按讚人數:  47
# 標題:  #圖多 可愛喵喵們(⁎⁍̴̛ᴗ⁍̴̛⁎)  ; 貼文時間:  2019-12-01T08:44:25.791Z  ; 留言人數:  1 ; 按讚人數:  43
# 標題:  你們吸貓，我被貓吸  ; 貼文時間:  2019-11-30T19:10:22.899Z  ; 留言人數:  2 ; 按讚人數:  34
# 標題:  #貓 擁有狗靈魂的貓  ; 貼文時間:  2019-12-01T11:43:58.401Z  ; 留言人數:  3 ; 按讚人數:  25
# 標題:  寵物過世碰到的外套  ; 貼文時間:  2019-12-01T09:23:54.879Z  ; 留言人數:  3 ; 按讚人數:  22
# 標題:  兔兔的睡姿⋯⋯  ; 貼文時間:  2019-12-01T09:01:55.400Z  ; 留言人數:  5 ; 按讚人數:  21
# 標題:  我家的紅貴賓到底是不是人轉世？  ; 貼文時間:  2019-12-01T06:13:52.856Z  ; 留言人數:  5 ; 按讚人數:  18
# 標題:  來嘛~~來吸我啊~  ; 貼文時間:  2019-12-01T11:56:53.031Z  ; 留言人數:  1 ; 按讚人數:  17
# 標題:  請問⋯妳是在哈囉？  ; 貼文時間:  2019-11-30T19:16:39.494Z  ; 留言人數:  2 ; 按讚人數:  17
# 標題:  我養了三隻蟲？🐛  ; 貼文時間:  2019-12-01T12:17:06.699Z  ; 留言人數:  1 ; 按讚人數:  15
# 標題:  基隆瑞芳深澳坑走失協找 拜託❗️❗️  ; 貼文時間:  2019-12-01T12:22:04.478Z  ; 留言人數:  2 ; 按讚人數:  14
# 標題:  虎爺公的細漢欸（小弟）  ; 貼文時間:  2019-11-30T19:16:31.808Z  ; 留言人數:  0 ; 按讚人數:  12
# 標題:  餵養的浪貓得了乳腺瘤  ; 貼文時間:  2019-12-02T05:29:49.540Z  ; 留言人數:  0 ; 按讚人數:  11
# 標題:  送養  ; 貼文時間:  2019-12-02T02:36:37.309Z  ; 留言人數:  1 ; 按讚人數:  11
# 標題:  你有看過這隻狗嗎？  ; 貼文時間:  2019-12-01T20:33:16.869Z  ; 留言人數:  2 ; 按讚人數:  11
# 標題:  中壢/米克斯狗女兒走失  ; 貼文時間:  2019-12-01T10:58:09.738Z  ; 留言人數:  0 ; 按讚人數:  11
# 標題:  淘寶寵物用品開箱&心得📦🐱  ; 貼文時間:  2019-12-01T06:19:59.473Z  ; 留言人數:  9 ; 按讚人數:  11
# 標題:  #協尋 玄鳳鸚鵡（已找到愛鳥 謝謝大家 謝謝好心人）  ; 貼文時間:  2019-12-01T05:33:55.211Z  ; 留言人數:  2 ; 按讚人數:  11
# 標題:  睡到投降的傻布偶小貓  ; 貼文時間:  2019-12-01T02:10:49.971Z  ; 留言人數:  1 ; 按讚人數:  11
# 標題:  吉娃娃才不吉敗咧  ; 貼文時間:  2019-12-01T09:17:16.567Z  ; 留言人數:  7 ; 按讚人數:  10
# 標題:  她是真的不是假的🌚  ; 貼文時間:  2019-12-01T16:18:44.132Z  ; 留言人數:  0 ; 按讚人數:  9
# 標題:  #圖 板橋貓咪走失  ; 貼文時間:  2019-12-02T03:50:17.266Z  ; 留言人數:  3 ; 按讚人數:  8
# 標題:  我的心已融化  ; 貼文時間:  2019-12-01T03:09:54.454Z  ; 留言人數:  2 ; 按讚人數:  8
# 標題:  #急#刺蝟  ; 貼文時間:  2019-12-02T05:06:34.886Z  ; 留言人數:  5 ; 按讚人數:  7

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''

commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']
    
print(commentCount/ len(data), likeCount/len(data))
# Out:
# 5.8 102.56666666666666
